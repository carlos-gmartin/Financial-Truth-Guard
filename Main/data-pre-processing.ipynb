# %%
import os # Accessing directory structure
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #Plotting

# %%
print(os.listdir('../'))

# looking at the data
for line in open('../DataSet/train.tsv', 'r').readlines():
    print(line.strip('\n'))

# %%
def read_dataframe(tsv_file: str) -> pd.DataFrame:
    # creates a "dataframe" or "df" for short. This is similar to a 2-D python dict.
    df = pd.read_csv(tsv_file, delimiter='\t', dtype=object)
    
    # replaces all "null" or "NaN" values with an empty string
    df.fillna("", inplace=True)
    
    # labels the columns in the dataset using the data dictionary described in the README
    df.columns = [
        'id',                # Column 1: the ID of the statement ([ID].json).
        'label',             # Column 2: the label.
        'statement',         # Column 3: the statement.
        'subjects',          # Column 4: the subject(s).
        'speaker',           # Column 5: the speaker.
        'speaker_job_title', # Column 6: the speaker's job title.
        'state_info',        # Column 7: the state info.
        'party_affiliation', # Column 8: the party affiliation.
        
        # Column 9-13: the total credit history count, including the current statement.
        'count_1', # barely true counts.
        'count_2', # false counts.
        'count_3', # half true counts.
        'count_4', # mostly true counts.
        'count_5', # pants on fire counts.
        
        'context' # Column 14: the context (venue / location of the speech or statement).
    ]
    return df

df = read_dataframe('../DataSet/train.tsv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10239 entries, 0 to 10238
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10239 non-null  object
#  1   label              10239 non-null  object
#  2   statement          10239 non-null  object
#  3   subjects           10239 non-null  object
#  4   speaker            10239 non-null  object
#  5   speaker_job_title  10239 non-null  object
#  6   state_info         10239 non-null  object
#  7   party_affiliation  10239 non-null  object
#  8   count_1            10239 non-null  object
#  9   count_2            10239 non-null  object
#  10  count_3            10239 non-null  object
#  11  count_4            10239 non-null  object
#  12  count_5            10239 non-null  object
#  13  context            10239 non-null  object
# dtypes: object(14)
# memory usage: 1.1+ MB

# %%
df.head(10)
# Out:
#            id        label                                          statement  \
# 0  10540.json    half-true  When did the decline of coal start? It started...
# 1    324.json  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 2   1123.json        false  Health care reform legislation is likely to ma...
# 3   9028.json    half-true  The economic turnaround started at the end of ...
# 4  12465.json         true  The Chicago Bears have had more starting quart...
# 5   2342.json  barely-true  Jim Dunnam has not lived in the district he re...
# 6    153.json    half-true  I'm the only person on this stage who has work...
# 7   5602.json    half-true  However, it took $19.5 million in Oregon Lotte...
# 8   9741.json  mostly-true  Says GOP primary opponents Glenn Grothman and ...
# 9   7115.json  mostly-true  For the first time in history, the share of th...
#
#                                     subjects                 speaker  \
# 0         energy,history,job-accomplishments          scott-surovell
# 1                             foreign-policy            barack-obama
# 2                                health-care            blog-posting
# 3                               economy,jobs           charlie-crist
# 4                                  education               robin-vos
# 5                       candidates-biography  republican-party-texas
# 6                                     ethics            barack-obama
# 7                                       jobs          oregon-lottery
# 8  energy,message-machine-2014,voting-record           duey-stroebel
# 9                                  elections         robert-menendez
#
#             speaker_job_title  state_info party_affiliation count_1 count_2  \
# 0              State delegate    Virginia          democrat       0       0
# 1                   President    Illinois          democrat      70      71
# 2                                                      none       7      19
# 3                                 Florida          democrat      15       9
# 4  Wisconsin Assembly speaker   Wisconsin        republican       0       3
# 5                                   Texas        republican       3       1
# 6                   President    Illinois          democrat      70      71
# 7                                              organization       0       0
# 8        State representative   Wisconsin        republican       0       0
# 9                U.S. Senator  New Jersey          democrat       1       3
#
#   count_3 count_4 count_5                                   context
# 0       1       1       0                           a floor speech.
# 1     160     163       9                                    Denver
# 2       3       5      44                            a news release
# 3      20      19       2                       an interview on CNN
# 4       2       5       1                 a an online opinion-piece
# 5       1       3       1                          a press release.
# 6     160     163       9  a Democratic debate in Philadelphia, Pa.
# 7       1       0       1                                a website
# 8       0       1       0                           an online video
# 9       1       3       0                                  a speech

# %%
df.loc[df['subjects'] == 'economy,jobs']
# Out:
#                id        label  \
# 3       9028.json    half-true
# 113    10423.json         true
# 132     7803.json  barely-true
# 192     9289.json    half-true
# 202     6265.json  barely-true
# ...           ...          ...
# 9894    5686.json         true
# 9922    6672.json  mostly-true
# 9985    9715.json         true
# 10172   6653.json    half-true
# 10231   4886.json    half-true
#
#                                                statement      subjects  \
# 3      The economic turnaround started at the end of ...  economy,jobs
# 113    The economy is creating jobs at the fastest pa...  economy,jobs
# 132    We are already almost halfway to our 2010 goal...  economy,jobs
# 192    Every single one of the 41 Republican senators...  economy,jobs
# 202    The state of Ohio has one of the lowest unempl...  economy,jobs
# ...                                                  ...           ...
# 9894   We were the No. 1 job creator in America in Fe...  economy,jobs
# 9922   Were seeing now 30 straight months of private-...  economy,jobs
# 9985   Its been 17 years that weve had unemployment h...  economy,jobs
# 10172  Weve got 7.2 percent unemployment (in Ohio), b...  economy,jobs
# 10231  Eighty percent of the net new jobs created in ...  economy,jobs
#
#                  speaker                     speaker_job_title state_info  \
# 3          charlie-crist                                          Florida
# 113         barack-obama                             President   Illinois
# 132           rick-scott                              Governor    Florida
# 192       facebook-posts                  Social media posting
# 202         bill-johnson                   U.S. representative       Ohio
# ...                  ...                                   ...        ...
# 9894         john-kasich  Governor of Ohio as of Jan. 10, 2011       Ohio
# 9922       julian-castro                    Mayor, San Antonio      Texas
# 9985   dennis-richardson                  state representative     Oregon
# 10172        rob-portman                U.S. senator from Ohio       Ohio
# 10231         david-frum           Senior editor, The Atlantic
#
#       party_affiliation count_1 count_2 count_3 count_4 count_5  \
# 3              democrat      15       9      20      19       2
# 113            democrat      70      71     160     163       9
# 132          republican      28      23      38      34       7
# 192                none      14      18      15      11      36
# 202          republican       2       1       0       0       0
# ...                 ...     ...     ...     ...     ...     ...
# 9894         republican       9       8      10      18       3
# 9922           democrat       0       0       3       3       0
# 9985         republican       0       4       1       2       0
# 10172        republican       3       5      11      11       1
# 10231              none       0       0       1       1       0
#
#                                  context
# 3                    an interview on CNN
# 113       the State of the Union address
# 132                 2013-14 veto message
# 192        a meme shared on social media
# 202        a telephone town hall meeting
# ...                                  ...
# 9894          an interview with Fox News
# 9922   an interview on "Meet the Press."
# 9985                   a campaign debate
# 10172             a television interview
# 10231       a New York magazine article.
#
# [125 rows x 14 columns]
